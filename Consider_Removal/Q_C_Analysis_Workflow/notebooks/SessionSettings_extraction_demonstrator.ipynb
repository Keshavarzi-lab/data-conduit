# %% [markdown]
# ## **SessionSettings Data Extraction Demonstrations**
# ---------------
# This notebook is intended to provide a brief demonstrator on how to use a number of the utilities that have been included to simplify the process of checking metadata from Bonsai Sessions.
#
#
# This includes:
