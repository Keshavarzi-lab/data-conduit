# %%
# read pickled data to inspect
import pickle

# %%
# snapshot best data example
filepath = '/home/callum/Keshavarzi-Lab-Workspace/data-conduit/datasets/firstdata/BonsaiFiles/FbR_M01569522/Day_11/2026-04-08T14-53-51/DLC/FbR_D11_allDark1DLC_Resnet50_AllDarkShapingApr13shuffle1_snapshot_best-100_full.pickle'
with open(filepath, 'rb') as f:
    data = pickle.load(f)

data
# Out:
# dict_keys(['metadata', 'frame0000', 'frame0001', 'frame0002', 'frame0003', 'frame0004', 'frame0005', 'frame0006', 'frame0007', 'frame0008', 'frame0009', 'frame0010', 'frame0011', 'frame0012', 'frame0013', 'frame0014', 'frame0015', 'frame0016', 'frame0017', 'frame0018', 'frame0019', 'frame0020', 'frame0021', 'frame0022', 'frame0023', 'frame0024', 'frame0025', 'frame0026', 'frame0027', 'frame0028', 'frame0029', 'frame0030', 'frame0031', 'frame0032', 'frame0033', 'frame0034', 'frame0035', 'frame0036', 'frame0037', 'frame0038', 'frame0039', 'frame0040', 'frame0041', 'frame0042', 'frame0043', 'frame0044', 'frame0045', 'frame0046', 'frame0047', 'frame0048', 'frame0049', 'frame0050', 'frame0051', 'frame0052', 'frame0053', 'frame0054', 'frame0055', 'frame0056', 'frame0057', 'frame0058', 'frame0059', 'frame0060', 'frame0061', 'frame0062', 'frame0063', 'frame0064', 'frame0065', 'frame0066', 'frame0067', 'frame0068', 'frame0069', 'frame0070', 'frame0071', 'frame0072', 'frame0073', 'frame0074', 
# ...

# %%
len(data)
# Out:
# 7355

# %%
data['metadata']
# Out:
# {'nms radius': None,
#  'minimal confidence': None,
#  'sigma': 1,
#  'PAFgraph': None,
#  'PAFinds': array([], dtype=int64),
#  'all_joints': [[0], [1], [2], [3], [4]],
#  'all_joints_names': ['nose', 'lear', 'rear', 'body', 'tailbase'],
#  'nframes': 7354,
#  'key_str_width': 4}

# %%
print(data['frame0000'].keys())
print(data['frame7353'].keys())
# Out:
# dict_keys(['coordinates', 'confidence', 'costs'])
# dict_keys(['coordinates', 'confidence', 'costs'])

# %%
data['frame0000']['coordinates']
# Out:
# ([array([[153.47656, 224.5293 ]], dtype=float32),
#   array([[150.79688, 231.79688]], dtype=float32),
#   array([[158.17773, 226.66602]], dtype=float32),
#   array([[163.92322, 238.94727]], dtype=float32),
#   array([[175.56055, 252.90576]], dtype=float32)],)
